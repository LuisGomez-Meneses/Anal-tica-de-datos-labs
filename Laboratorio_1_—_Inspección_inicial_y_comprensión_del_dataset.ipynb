# %%
import pandas as pd
df = pd.read_csv("/content/ventas.csv")

# %%
df.head(-3)
# Out:
#            fecha  id_cliente              producto categoria        ciudad  \
# 0     2025-11-03       13375           Guantes gym  Deportes        Bogota
# 1     2025-06-05       19441             Licuadora     Hogar  Barranquilla
# 2     2025-06-02       10603           Tapete yoga  Deportes        Bogota
# 3     2025-11-15       10698    Bicicleta estatica  Deportes        Bogota
# 4     2025-08-29       15539         Tenis urbanos      Moda          Cali
# ...          ...         ...                   ...       ...           ...
# 4812  2025-11-02       10210    Bicicleta estatica  Deportes      Medellin
# 4813  2025-04-23       12616  Chaqueta impermeable      Moda      Medellin
# 4814  2025-07-18       11960             Jean slim      Moda  Barranquilla
# 4815  2025-01-13       12522        Mancuernas 5kg  Deportes        bogota
# 4816  2025-02-18       18487        Set de sabanas     Hogar      Medellin
#
#       unidades  precio_unitario  descuento     canal    ventas
# 0            4          48100.0       0.05  En linea  182780.0
# 1            5          81800.0       0.00    Tienda  409000.0
# 2            2          75200.0       0.10  En linea  135360.0
# 3            3          42300.0       0.00    Tienda  126900.0
# 4            1          94500.0       0.05    Tienda   89775.0
# ...        ...              ...        ...       ...       ...
# 4812         2          32500.0       0.30  En linea   45500.0
# 4813         2          31800.0       0.15    Tienda   54060.0
# 4814         4          30100.0       0.20    Tienda   96320.0
# 4815         3          40900.0       0.00    Tienda  122700.0
# 4816         2          48800.0       0.20  En linea   78080.0
#
# [4817 rows x 10 columns]

# %%
df.shape
# Out:
# (4820, 10)

# %%
df.columns
# Out:
# Index(['fecha', 'id_cliente', 'producto', 'categoria', 'ciudad', 'unidades',
#        'precio_unitario', 'descuento', 'canal', 'ventas'],
#       dtype='object')

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 4820 entries, 0 to 4819
# Data columns (total 10 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   fecha            4820 non-null   object
#  1   id_cliente       4820 non-null   int64
#  2   producto         4820 non-null   object
#  3   categoria        4820 non-null   object
#  4   ciudad           4820 non-null   object
#  5   unidades         4820 non-null   int64
#  6   precio_unitario  4820 non-null   float64
#  7   descuento        4702 non-null   float64
#  8   canal            4820 non-null   object
#  9   ventas           4796 non-null   float64
# dtypes: float64(3), int64(2), object(5)
# memory usage: 376.7+ KB

# %%
df["fecha"] = pd.to_datetime(df["fecha"])

# %%
df['producto']=df['producto'].astype(str)
df['categoria']=df['categoria'].astype(str)
df['ciudad']=df['ciudad'].astype(str)
df['canal']=df['canal'].astype(str)

# %%
type(df)
# Out:
# pandas.core.frame.DataFrame

# %%
type(df['ciudad'])
# Out:
# pandas.core.series.Series

# %%
type(df['ciudad'][0])
# Out:
# str

# %%
df.dtypes
# Out:
# fecha              datetime64[ns]
# id_cliente                  int64
# producto                   object
# categoria                  object
# ciudad                     object
# unidades                    int64
# precio_unitario           float64
# descuento                 float64
# canal                      object
# ventas                    float64
# dtype: object

# %%
df['fecha'].unique()
# Out:
# <DatetimeArray>
# ['2025-11-03 00:00:00', '2025-06-05 00:00:00', '2025-06-02 00:00:00',
#  '2025-11-15 00:00:00', '2025-08-29 00:00:00', '2025-03-04 00:00:00',
#  '2025-08-23 00:00:00', '2025-07-08 00:00:00', '2025-09-11 00:00:00',
#  '2025-08-14 00:00:00',
#  ...
#  '2025-06-01 00:00:00', '2025-01-28 00:00:00', '2025-12-28 00:00:00',
#  '2025-05-22 00:00:00', '2025-06-09 00:00:00', '2025-04-16 00:00:00',
#  '2025-11-25 00:00:00', '2025-07-04 00:00:00', '2025-07-29 00:00:00',
#  '2025-02-02 00:00:00']
# Length: 365, dtype: datetime64[ns]

# %%
df["categoria"].unique()
# Out:
# array(['Deportes', 'Hogar', 'Moda', 'Tecnologia'], dtype=object)

# %%
df["ciudad"].unique()
# Out:
# array(['Bogota', 'Barranquilla', 'Cali', 'Medellin', 'MEDELLIN', 'bogota'],
#       dtype=object)

# %%
df["canal"].unique()
# Out:
# array(['En linea', 'Tienda'], dtype=object)

# %%
df["producto"].nunique()
# Out:
# 20

# %%
df["id_cliente"].nunique()
# Out:
# 3874
